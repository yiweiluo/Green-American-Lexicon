# %%
import pickle
import numpy as np
import pandas as pd
from collections import Counter

# %%
# Functions for importing & cleaning relevant tweets
def lower(s):
    return s.lower()

def tweet_imports(filename):
    imp = pd.read_pickle(filename)
    imp = imp.drop_duplicates()
    imp['tweet_clean'] = imp['tweet'].str.replace('http\S+|www.\S+|pic.twitter.com\S+', '', case=False)
    imp['tweet_clean'] =imp['tweet_clean'].replace('[^A-Za-z0-9 ]+','',regex=True)
    imp['tweet_clean'] = imp['tweet_clean'].apply(lower)#map(lambda x: x.lower(), imp['tweet_clean'])
    imp['date'] = pd.to_datetime(imp['date'])
    return imp

# %%
def log_odds(l1,l2):
    counts_l1 = Counter(l1)
    counts_l2 = Counter(l2)
    counts_l1.update({t: 0.5 for t in counts_l2 if t not in counts_l1})
    counts_l2.update({t: 0.5 for t in counts_l1 if t not in counts_l2})
    sum_1 = sum(counts_l1.values())
    sum_2 = sum(counts_l2.values())
    freqs_1 = {t: counts_l1[t]*1./sum_1 for t in counts_l1}
    freqs_2 = {t: counts_l2[t]*1./sum_2 for t in counts_l2}
    odds_1 = {t: freqs_1[t]/(1-freqs_1[t]) for t in freqs_1}
    odds_2 = {t: freqs_2[t]/(1-freqs_2[t]) for t in freqs_2}
    odds_ratios = {t: odds_1[t]/odds_2[t] for t in odds_1}
    return {t: np.log(odds_ratios[t]) for t in odds_ratios}

# %%
from nltk.tokenize import MWETokenizer
tk = MWETokenizer()
tk.add_mwe(('climate','change'))
tk.add_mwe(('global','warming'))
tk.add_mwe(('one','world'))
tk.add_mwe(('new','jobs'))
tk.add_mwe(('carbon','tax'))
tk.add_mwe(('carbon','neutral'))

# %%
tk.tokenize('Global warming is exaggerated'.lower().split())
# Out:
# ['global_warming', 'is', 'exaggerated']

# %%
import nltk

from nltk.stem.porter import *
stemmer = PorterStemmer()

# %%
import re

# %%
liwc_dict = {}
with open('/Users/yiweiluo/Downloads/datasets/en_liwc.txt','r') as f:
    for line in f:
        split_line = line.strip().split(': ')
        cat = split_line[0]
        cat_words = split_line[1].split()
        cat_words = [w.split('*')[0] for w in cat_words]
        liwc_dict[cat] = cat_words

# %%
liwc_dict.keys()
# Out:
# dict_keys(['Ppron', 'Inhib', 'Space', 'Filler', 'Ipron', 'Time', 'Percept', 'Verbs', 'Quant', 'Discrep', 'Relativ', 'Affect', 'You', 'Cause', 'Prep', 'Relig', 'Body', 'Bio', 'We', 'Assent', 'Incl', 'Leisure', 'AuxVb', 'Hear', 'They', 'Posemo', 'Article', 'Excl', 'Home', 'Friends', 'Present', 'Numbers', 'CogMech', 'I', 'Work', 'Tentat', 'Ingest', 'Motion', 'Anger', 'Achiev', 'Swear', 'Death', 'Social', 'Nonflu', 'Family', 'Pronoun', 'Funct', 'Feel', 'Certain', 'Insight', 'Humans', 'Sad', 'Past', 'See', 'Future', 'Adverbs', 'SheHe', 'Money', 'Negate', 'Health', 'Conj', 'Anx', 'Negemo', 'Sexual'])

# %%
pd.DataFrame.from_dict(liwc_dict,orient='index')
# Out:
#               0         1         2        3            4         5    \
# Ppron       y'all       ive      weve   she'll        you'd    thoust
# Inhib   discourag      held      duti   hesita      harness   blocked
# Space     bending   breadth    taller   spaced         area   shaping
# Filler        ykn        rr    ohwell     blah        imean     yakno
# Ipron        this     whats    thatll      itd           it  whatever
# ...           ...       ...       ...      ...          ...       ...
# Health      gland    therap  swelling   sickly  thermometer    addict
# Conj          and     altho        as  because           if      till
# Anx       stunned     shaky    terror     fear       hesita     tense
# Negemo      gloom  liabilit      vile   tortur      protest       ugh
# Sexual       jizz     pussy   makeout    libid       incest     horny
#
#              6          7          8          9    ...   906   907   908  \
# Ppron       mine        his       shes      theyd  ...  None  None  None
# Inhib   suppress      yield      tight  contradic  ...  None  None  None
# Space       over     remote     bottom   roommate  ...  None  None  None
# Filler   youknow  idontknow       like       None  ...  None  None  None
# Ipron     anyone     itself    somebod      nobod  ...  None  None  None
# ...          ...        ...        ...        ...  ...   ...   ...   ...
# Health     wheez    thyroid  physician     twitch  ...  None  None  None
# Conj     whereas       when        cuz        til  ...  None  None  None
# Anx      nervous    fearful      inhib   reluctan  ...  None  None  None
# Negemo    troubl     hating      messy       hate  ...  None  None  None
# Sexual  erection      titty       hump       dick  ...  None  None  None
#
#          909   910   911   912   913   914   915
# Ppron   None  None  None  None  None  None  None
# Inhib   None  None  None  None  None  None  None
# Space   None  None  None  None  None  None  None
# Filler  None  None  None  None  None  None  None
# Ipron   None  None  None  None  None  None  None
# ...      ...   ...   ...   ...   ...   ...   ...
# Health  None  None  None  None  None  None  None
# Conj    None  None  None  None  None  None  None
# Anx     None  None  None  None  None  None  None
# Negemo  None  None  None  None  None  None  None
# Sexual  None  None  None  None  None  None  None
#
# [64 rows x 916 columns]

# %%
RELEVANT_LIWC_CATS = ['Inhib','Affect','Cause','Relig','Body','Bio','Posemo','Home','Work','Anger','Social',
                     'Family','Humans','Sad','Future','Past','Money','Negate','Health','Negemo']

# %%
def log_odds_liwc(odds_dict,liwc_cat):
    liwc_words = liwc_dict[liwc_cat]
    liwc_odds = {w: odds_dict[w] for w in liwc_words if w in odds_dict}
    return liwc_odds

# %% [markdown]
# # News data

# %%
news_df = pd.read_pickle('/Users/yiweiluo/Dropbox/research/QP2/code/Fox_and_friends/\
all_urls_meta_and_fulltext_df_2020.pkl')

# %%
news_df = news_df.reset_index()
climate_news = news_df[news_df['topic'] == 'cc']

# %%
climate_news.head()
# Out:
#       index  bad NYT  date domain  \
# 1600   1600    False  None   :///
# 1601   1601    False  None   :///
# 1602   1602    False  None   :///
# 1603   1603    False  None   :///
# 1604   1604    False  None   :///
#
#                                                fulltext stance title topic  \
# 1600    If you can't sleep as much as you need durin...   anti  None    cc
# 1601  Paper says draft document by scientists direct...   anti  None    cc
# 1602  The public's concern about global warming has ...   anti  None    cc
# 1603  The federal report by dozens of U.S. governmen...   anti  None    cc
# 1604    File photo - A statue of the Virgin Mary is ...   anti  None    cc
#
#                                                     url
# 1600  foxnews.com/lifestyle/climate-change-might-be-...
# 1601  foxnews.com/opinion/climate-policy-get-ready-f...
# 1602  foxnews.com/opinion/physicist-dont-fall-for-th...
# 1603  foxnews.com/politics/junk-science-studies-behi...
# 1604  foxnews.com/science/10-years-after-hurricane-k...

# %%
climate_news[climate_news['stance'] == 'anti'].shape
# Out:
# (5067, 9)

# %% [markdown]
# Tokenize and pre-process fulltext from each side:

# %%
pro_news_tokens = [tk.tokenize(climate_news.iloc[row_ix]['fulltext'].lower().split()) 
                   for row_ix in range(len(climate_news.index))
                  if climate_news.iloc[row_ix]['fulltext'] is not None and 
                   len(climate_news.iloc[row_ix]['fulltext']) > 0 and climate_news.iloc[row_ix]['stance'] == 'pro']
anti_news_tokens = [tk.tokenize(climate_news.iloc[row_ix]['fulltext'].lower().split()) 
                    for row_ix in range(len(climate_news.index))
                  if climate_news.iloc[row_ix]['fulltext'] is not None and 
                    len(climate_news.iloc[row_ix]['fulltext']) > 0 and climate_news.iloc[row_ix]['stance'] == 'anti']

# %%
pro_news_tokens = [item for sublist in pro_news_tokens for item in sublist]
anti_news_tokens = [item for sublist in anti_news_tokens for item in sublist]

# %%
pickle.dump(pro_news_tokens,open('pro_news_tokens.pkl','wb'))
pickle.dump(anti_news_tokens,open('anti_news_tokens.pkl','wb'))

# %% [markdown]
# Remove punctuation from tokens and get stems:

# %%
import string
string.punctuation
punctuations = string.punctuation + '“'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
pro_news_tokens = [item.translate(str.maketrans('', '', punctuations))
                   for item in pro_news_tokens]
anti_news_tokens = [item.translate(str.maketrans('', '', punctuations))
                   for item in anti_news_tokens]

# %%
from spacy.lemmatizer import Lemmatizer
#from spacy.lookups import Lookups
#lookups = Lookups()
#lookups.add_table("lemma_rules", {"noun": [["s", ""]]})
lemmatizer = Lemmatizer()
lemmas = lemmatizer("ducks", "NOUN")

import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize('global_warming')
# Out:
# 'global_warming'

# %%
lemmatizer.lemmatize('ducks')
# Out:
# 'duck'

# %%
# pro_news_lemmas = [lemmatizer.lemmatize(item) for item in pro_news_tokens]
# anti_news_lemmas = [lemmatizer.lemmatize(item) for item in anti_news_tokens]
pro_news_stems = [stemmer.stem(item) for item in pro_news_tokens]
anti_news_stems = [stemmer.stem(item) for item in anti_news_tokens]

# %%
anti_news_lemmas[:50]
# Out:
# ['if',
#  'you',
#  'cant',
#  'sleep',
#  'a',
#  'much',
#  'a',
#  'you',
#  'need',
#  'during',
#  'the',
#  'week',
#  'you',
#  'may',
#  'be',
#  'able',
#  'to',
#  'make',
#  'up',
#  'for',
#  'it',
#  'on',
#  'the',
#  'weekend',
#  'istock',
#  'rising',
#  'temperature',
#  'caused',
#  'by',
#  'climatechange',
#  'seem',
#  'to',
#  'be',
#  'disrupting',
#  'america’s',
#  'sleep',
#  'pattern',
#  'according',
#  'to',
#  'a',
#  'new',
#  'study',
#  'a',
#  'temperature',
#  'increase',
#  'of',
#  '18',
#  'degree',
#  'fahrenheit',
#  'cause']

# %%
print(len(pro_news_lemmas))
print(len(anti_news_lemmas))
# Out:
# 23597279
# 3577618

# %%
# pickle.dump(pro_news_lemmas,open('pro_news_lemmas.pkl','wb'))
# pickle.dump(anti_news_lemmas,open('anti_news_lemmas.pkl','wb'))
pickle.dump(pro_news_stems,open('pro_news_stems.pkl','wb'))
pickle.dump(anti_news_stems,open('anti_news_stems.pkl','wb'))

# %%
#pro_anti_news_odds = log_odds(pro_news_lemmas,anti_news_lemmas)
pro_anti_news_odds_stems = log_odds(pro_news_stems,anti_news_stems)

# %%
#sorted_pro_anti_news_odds = sorted(pro_anti_news_odds.items(), key=lambda x:x[1])
sorted_pro_anti_news_odds_stems = sorted(pro_anti_news_odds_stems.items(), key=lambda x:x[1])

# %%
sorted_pro_anti_news_odds[-100:]
# Out:
# [('amory', 4.397528773343627),
#  ('inaudible', 4.403259575107505),
#  ('zabel', 4.412727443744629),
#  ('bello', 4.416493968891274),
#  ('lovins', 4.418383075494853),
#  ('discontinuing', 4.429577476347927),
#  ('pensum', 4.435116692745144),
#  ('typemates', 4.435116692745144),
#  ('serif', 4.43879998051262),
#  ('classsocialbuttonhighlightspan', 4.43879998051262),
#  ('kouddous', 4.467787856195369),
#  ('energypol', 4.467787856195369),
#  ('g77', 4.478445277722948),
#  ('potosí', 4.478445277722948),
#  ('lidy', 4.492480765244145),
#  ('dargis', 4.513171412608864),
#  ('naidoo', 4.513171412608864),
#  ('shiva', 4.5300925018533125),
#  ('btnffcf0d', 4.546732032613432),
#  ('nacpil', 4.550026970861521),
#  ('getcookiesessname', 4.550026970861521),
#  ('kumi', 4.5565844561101585),
#  ('angelica', 4.559860009965532),
#  ('abdel', 4.563099221833838),
#  ('font', 4.591901593898817),
#  ('kamat', 4.6013209428690995),
#  ('nytoday', 4.644141532969928),
#  ('wahu', 4.653083597399471),
#  ('kaara', 4.653083597399471),
#  ('alternateside', 4.685203612685954),
#  ('times’s', 4.69522574294577),
#  ('nationem’s', 4.713534542825433),
#  ('workp', 4.713534542825433),
#  ('valuedonatea', 4.713534542825433),
#  ('ffcf0d', 4.713534542825433),
#  ('articlebody', 4.732899206466607),
#  ('sunita', 4.738363785641383),
#  ('nytodaynytimescom', 4.749204169599664),
#  ('nermeen', 4.781037604389294),
#  ('mmhmm', 4.788840111727624),
#  ('environmentnslp', 4.794008166588839),
#  ('2396200', 4.804264836161595),
#  ('saleemul', 4.83689061404596),
#  ('anjali', 4.839356748892573),
#  ('yanez', 4.856451478711859),
#  ('msg', 4.882737806848655),
#  ('huq', 4.903742460782333),
#  ('nytodaycom', 4.910647103183292),
#  ('maté', 4.910647103183292),
#  ('dealbook', 4.912938097281322),
#  ('telechargecom', 4.926574926339756),
#  ('2810', 4.934463478915057),
#  ('lovera', 4.93556392031415),
#  ('khor', 4.95330308346354),
#  ('ivonne', 4.962056043979182),
#  ('emthe', 4.985738994489519),
#  ('kert', 4.994213790886645),
#  ('briefingnytimescom', 5.004707278360218),
#  ('gonzález', 5.061518870384624),
#  ('timesread', 5.115275799534992),
#  ('twitterread', 5.115275799534992),
#  ('coverageread', 5.115275799534992),
#  ('arguesread', 5.115275799534992),
#  ('parkread', 5.115275799534992),
#  ('grode', 5.206331002152567),
#  ('reprint', 5.219073744300134),
#  ('hrefjavascriptvoid0input', 5.239892045680091),
#  ('typebutton', 5.239892045680091),
#  ('classbtn', 5.239892045680091),
#  ('namesubmitsailthru', 5.239892045680091),
#  ('isuserloggedin', 5.241540893022054),
#  ('isherwood', 5.26595282997865),
#  ('beeman', 5.291351698213414),
#  ('democracynoworg', 5.306904534739353),
#  ('moglen', 5.334304271261137),
#  ('d’escoto', 5.352162396883912),
#  ('climatech', 5.475505679637705),
#  ('greenweiskel', 5.560453483066064),
#  ('signup', 5.588791696652536),
#  ('nasheed', 5.589955206268067),
#  ('endread', 5.625368557411459),
#  ('dakotaread', 5.625368557411459),
#  ('burnread', 5.625368557411459),
#  ('dietsread', 5.625368557411459),
#  ('us”read', 5.625368557411459),
#  ('scatsniffing', 5.62649030487295),
#  ('ted’s', 5.630964754677054),
#  ('biello', 5.636529811071981),
#  ('solón', 5.742782112700728),
#  ('loadarticleads', 5.75764186239202),
#  ('ismobileany', 5.75764186239202),
#  ('guggenheim', 5.761567453918205),
#  ('»', 5.765851446166416),
#  ('★', 6.039420776596855),
#  ('susman', 6.144268180177532),
#  ('papersubscribe', 6.17970724601943),
#  ('revkin', 6.3614755824086195),
#  ('more…', 6.481604318240899),
#  ('environmen', 6.521534207146741),
#  ('goodman', 7.686084326994018)]

# %%
#dict_odds = dict(pro_anti_news_odds)
dict_odds_stems = dict(pro_anti_news_odds_stems)

# %%
dict_odds['cause']
# Out:
# -0.30371170224634875

# %%
list(dict_odds.keys())[:5]
# Out:
# ['this', 'matter', 'is', 'best', 'disposed']

# %%
dict_odds['matter']
# Out:
# 0.12973077638690833

# %% [markdown]
# ## Of specific LIWC categories

# %%
for cat in RELEVANT_LIWC_CATS:
    odds = log_odds_liwc(dict_odds_stems,cat)
    pos = [w for w in odds if odds[w] > 0]
    neg = [w for w in odds if odds[w] < 0]
    print(cat,'Num pos:'+str(len(pos)),'Num neg:'+str(len(neg)))
    print('\n')
# Out:
# Inhib Num pos:31 Num neg:42
#
#
# Affect Num pos:268 Num neg:263
#
#
# Cause Num pos:19 Num neg:33
#
#
# Relig Num pos:46 Num neg:55
#
#
# Body Num pos:65 Num neg:58
#
#
# Bio Num pos:208 Num neg:148
#
#
# Posemo Num pos:127 Num neg:95
#
#
# Home Num pos:35 Num neg:24
#
#
# Work Num pos:111 Num neg:88
#
#
# Anger Num pos:43 Num neg:75
#
#
# Social Num pos:133 Num neg:94
#
#
# Family Num pos:21 Num neg:9
#
#
# Humans Num pos:16 Num neg:12
#
#
# Sad Num pos:30 Num neg:28
#
#
# Future Num pos:2 Num neg:15
#
#
# Past Num pos:47 Num neg:20
#
#
# Money Num pos:77 Num neg:33
#
#
# Negate Num pos:4 Num neg:23
#
#
# Health Num pos:84 Num neg:55
#
#
# Negemo Num pos:139 Num neg:165

# %%
sorted(log_odds_liwc(dict_odds_stems,'Inhib').items(),key=lambda x:x[1],reverse=True)
# Out:
# [('abstain', 2.3573022259258765),
#  ('taboo', 0.9783270965197011),
#  ('uptight', 0.9103730160703509),
#  ('repress', 0.8860457659255339),
#  ('blocker', 0.8458350176972818),
#  ('rigid', 0.808097016349421),
#  ('stiff', 0.6941521640551315),
#  ('constrain', 0.6585042594091605),
#  ('neglect', 0.45839466669439227),
#  ('prudish', 0.4403692597655841),
#  ('kept', 0.3281326334128129),
#  ('wait', 0.3086869412706238),
#  ('suppress', 0.295088870798877),
#  ('forbid', 0.2876075201285799),
#  ('avert', 0.26027176148051473),
#  ('stubborn', 0.24799821262081412),
#  ('block', 0.22453883580060882),
#  ('hangup', 0.2172256991763508),
#  ('conflict', 0.20342348723609113),
#  ('limit', 0.20230364795760597),
#  ('bound', 0.1493517243490618),
#  ('discourag', 0.14416838782199048),
#  ('tidi', 0.13718344655201958),
#  ('disciplin', 0.10722621919152978),
#  ('curtail', 0.10055925795084329),
#  ('avoid', 0.09716301072273872),
#  ('delay', 0.0658976857763626),
#  ('duti', 0.05160729774691386),
#  ('disregard', 0.04979310634081989),
#  ('rein', 0.02627365159839437),
#  ('control', 0.0158339538739567),
#  ('held', -0.0065085586030787955),
#  ('stop', -0.02173149379967263),
#  ('keep', -0.022142281248702378),
#  ('confin', -0.03045150553999054),
#  ('secur', -0.032620893467041445),
#  ('oppos', -0.047447423514514156),
#  ('retain', -0.06034643919553589),
#  ('prevent', -0.06995165916156808),
#  ('interfer', -0.0915123284918495),
#  ('requir', -0.09973766554932866),
#  ('defens', -0.12382855061168645),
#  ('veto', -0.12572111530199515),
#  ('hold', -0.12847637477340473),
#  ('barrier', -0.16754364300260133),
#  ('tight', -0.19548091878091844),
#  ('abandon', -0.19930973314371322),
#  ('fenc', -0.20399145478683295),
#  ('protect', -0.20556232974395292),
#  ('safe', -0.21840224835625932),
#  ('yield', -0.22737238503567703),
#  ('enclos', -0.22808582850732456),
#  ('restrain', -0.22882659560670962),
#  ('halt', -0.23465996481420462),
#  ('constrict', -0.2866799556729674),
#  ('curb', -0.2889236888082297),
#  ('restrict', -0.3043971329390614),
#  ('ignor', -0.33189452658891416),
#  ('refus', -0.35763582907947633),
#  ('conserv', -0.4327109775691689),
#  ('ban', -0.4648866504055993),
#  ('guard', -0.48298910294149),
#  ('refrain', -0.4911925118516117),
#  ('brake', -0.496404026448308),
#  ('contain', -0.5554938708966836),
#  ('forgot', -0.6032638107022786),
#  ('anal', -0.8813871348281649),
#  ('withhold', -1.0723505807580205),
#  ('prude', -1.1690688220805328),
#  ('withheld', -1.4675682211610552),
#  ('harness', -2.5553633407109784),
#  ('defenc', -2.596191392228116),
#  ('stopper', -3.9416595893330904)]

# %%
sorted(log_odds_liwc(dict_odds_stems,'Family').items(),key=lambda x:x[1],reverse=True)
# Out:
# [('exhusband', 1.538981971963861),
#  ('aunt', 1.4336253116748678),
#  ('wive', 1.0822257307087768),
#  ('stepchild', 1.0281560940797485),
#  ('mother', 0.810968578375855),
#  ('grandson', 0.7496928670305765),
#  ('daughter', 0.6498833711072465),
#  ('father', 0.6415741511502484),
#  ('brother', 0.5150061307002347),
#  ('grandkid', 0.4891600366587553),
#  ('bro', 0.4150519374458191),
#  ('wife', 0.4114039892250725),
#  ('sister', 0.39171447217692335),
#  ('spous', 0.3890774461785668),
#  ('ma', 0.3350114899330635),
#  ('parent', 0.26919839683769536),
#  ('cousin', 0.1961739967517232),
#  ('grandpa', 0.15268720184174966),
#  ('husband', 0.14847888980385401),
#  ('kin', 0.11186527873048616),
#  ('son', 0.009875050648873217),
#  ('granddad', -0.07045644870641832),
#  ('nephew', -0.0704566249324903),
#  ('pa', -0.12127684007382324),
#  ('mum', -0.3361599943861463),
#  ('mom', -0.511360607779277),
#  ('ex', -0.518481823848564),
#  ('dad', -0.5688226281709716),
#  ('momma', -0.9459255103565274),
#  ('stepkid', -1.1690688220805328)]

# %%
sorted(log_odds_liwc(dict_odds_stems,'Health').items(),key=lambda x:x[1],reverse=True)
# Out:
# [('pediatr', 2.8562874335146753),
#  ('sickest', 2.7627589282960634),
#  ('throb', 2.51981228380179),
#  ('flu', 2.4316736580705625),
#  ('hiv', 2.243185380020233),
#  ('estrogen', 2.2321297878193933),
#  ('thyroid', 2.0890287747665237),
#  ('sicker', 1.7213036558169006),
#  ('iv', 1.6493318224902662),
#  ('viagra', 1.6035205354544586),
#  ('mono', 1.3958810436171398),
#  ('xanax', 1.3958810436171398),
#  ('gynecolog', 1.3158382935905824),
#  ('obes', 1.1909341410522007),
#  ('aspirin', 1.1335169392867923),
#  ('asthma', 1.07377949222558),
#  ('intox', 0.9999868463115243),
#  ('physician', 0.9936238725240122),
#  ('addict', 0.9899880227133848),
#  ('pill', 0.9826980332180297),
#  ('lymph', 0.9103730160703509),
#  ('mammogram', 0.9103730160703509),
#  ('cancer', 0.8511253711429082),
#  ('checkup', 0.8458346550698607),
#  ('sick', 0.8226372337488799),
#  ('inflam', 0.7945423215062507),
#  ('orthoped', 0.7768415810928161),
#  ('cardio', 0.7768415810928161),
#  ('dose', 0.7367691370340242),
#  ('stiff', 0.6941521640551315),
#  ('vomit', 0.6767595452222585),
#  ('deaf', 0.663514789610848),
#  ('bipolar', 0.6635132491380866),
#  ('neurolog', 0.6392212632748318),
#  ('clinic', 0.6286354977254496),
#  ('swollen', 0.6226916834017548),
#  ('detox', 0.622690976696582),
#  ('glaucoma', 0.6226908589125476),
#  ('cramp', 0.6122212834574292),
#  ('vitamin', 0.5924800487346478),
#  ('numb', 0.5887902825886232),
#  ('medic', 0.5641226173033286),
#  ('heal', 0.4867823964310616),
#  ('fever', 0.4768446949452999),
#  ('diagnos', 0.47655200378122375),
#  ('dr', 0.47026664074223506),
#  ('immun', 0.4474931154585809),
#  ('alcohol', 0.4403752188959722),
#  ('overweight', 0.4403697877831786),
#  ('sinus', 0.44036933519659033),
#  ('mri', 0.44036933519659033),
#  ('ritalin', 0.4403692597655841),
#  ('cough', 0.43032031475251287),
#  ('doctor', 0.408375394693985),
#  ('infect', 0.4041129183398113),
#  ('wheez', 0.38907614931809703),
#  ('surgeon', 0.3713777843727629),
#  ('insulin', 0.3624081192542632),
#  ('scab', 0.335008777185748),
#  ('prozac', 0.335008777185748),
#  ('migrain', 0.335008777185748),
#  ('scrape', 0.3257075357735985),
#  ('patholog', 0.3177681881580056),
#  ('pain', 0.2804167141094679),
#  ('symptom', 0.2639912706685179),
#  ('insomnia', 0.2172258314883845),
#  ('syphili', 0.2172256991763508),
#  ('heartburn', 0.2172256660983676),
#  ('cyst', 0.2172256660983676),
#  ('ibuprofen', 0.2172256660983676),
#  ('rx', 0.2172256660983676),
#  ('tylenol', 0.2172256660983676),
#  ('vicodin', 0.2172256660983676),
#  ('life', 0.21276898333215388),
#  ('chronic', 0.18465161916255737),
#  ('drug', 0.13897356508013947),
#  ('tender', 0.13021482484230565),
#  ('exercis', 0.09756484578562893),
#  ('amput', 0.08369428800177318),
#  ('health', 0.04505953910995227),
#  ('diabet', 0.04447384965030533),
#  ('ulcer', 0.03490410528227671),
#  ('schizophren', 0.00958627349502839),
#  ('vertigo', 0.00958627349502839),
#  ('hiccup', -0.02963447675841313),
#  ('zoloft', -0.07045644870641832),
#  ('enema', -0.07045644870641832),
#  ('antacid', -0.07045644870641832),
#  ('stroke', -0.07045710723993388),
#  ('sore', -0.08163006063469336),
#  ('wound', -0.08478808260123596),
#  ('poison', -0.0967586008902346),
#  ('allerg', -0.11301628695715336),
#  ('fatigu', -0.1130165200650872),
#  ('weak', -0.12130606645309953),
#  ('dentist', -0.15746797532742082),
#  ('lump', -0.16354747957464508),
#  ('exhaust', -0.19967251400350913),
#  ('fat', -0.2177850495926132),
#  ('faint', -0.23751127348371362),
#  ('ill', -0.23867233055850384),
#  ('puss', -0.2527780571284162),
#  ('tingl', -0.25277811803152084),
#  ('sunburn', -0.252778422547486),
#  ('wash', -0.2760705471698809),
#  ('burp', -0.37056179177583737),
#  ('coma', -0.440830908168763),
#  ('blind', -0.4683076146807709),
#  ('farsighted', -0.4759215991675862),
#  ('std', -0.4759215991675862),
#  ('drows', -0.4759215991675862),
#  ('puk', -0.4759215991675862),
#  ('chiropract', -0.4759215991675862),
#  ('prognos', -0.4759215991675862),
#  ('unhealth', -0.4759216507956328),
#  ('pap', -0.4759217540517604),
#  ('healer', -0.4759219605641525),
#  ('bleed', -0.5110160312085422),
#  ('tire', -0.5416041061947418),
#  ('congest', -0.5453547533942174),
#  ('yawn', -0.546540377632141),
#  ('bandaid', -0.5629336287724371),
#  ('injur', -0.6113533649716638),
#  ('itch', -0.6659668739377971),
#  ('twitch', -0.7227827479923592),
#  ('xray', -0.7860787023388849),
#  ('ingest', -0.9177577387995725),
#  ('rehab', -1.0149206559453587),
#  ('nearsighted', -1.1690688220805328),
#  ('chlamydia', -1.1690688220805328),
#  ('derma', -1.1690688220805328),
#  ('advil', -1.1690688220805328),
#  ('hypotherm', -1.1690689160615864),
#  ('wart', -1.169069104023744),
#  ('gland', -1.2560824453447224),
#  ('digest', -1.5520893496176493),
#  ('decongest', -1.8622161389745333),
#  ('appendic', -1.8622161389745333),
#  ('therap', -2.5553633407109784)]

# %% [markdown]
# # Twitter data

# %%
pro_sentences_fuzzy_matched = pickle.load(open('fuzzy_matched_pro_sents.pkl','rb'))
anti_sentences_fuzzy_matched = pickle.load(open('fuzzy_matched_anti_sents.pkl','rb'))

# %%
anti_sentences_fuzzy_matched[:5]
# Out:
# [['finally',
#   'this',
#   'is',
#   'being',
#   'picked',
#   'up',
#   'like',
#   'good',
#   'cheese',
#   'its',
#   'taken',
#   'a',
#   'while',
#   'for',
#   'median',
#   'to',
#   'pick',
#   'up',
#   'but',
#   'good',
#   'clmate',
#   'shocker',
#   'nzs',
#   'zero',
#   'carbo',
#   'bill',
#   'goes',
#   'too',
#   'far',
#   'breaches',
#   'pariss',
#   'clmate',
#   'agreemen'],
#  ['appreciating',
#   'this',
#   'pieces',
#   'in',
#   'atest',
#   'edition',
#   'of',
#   'the',
#   'listener',
#   'we',
#   'note',
#   'tough',
#   'its',
#   'not',
#   'just',
#   'intentional',
#   'investor',
#   'its',
#   'carbo',
#   'investor',
#   'per'],
#  ['addressing',
#   'this',
#   'in',
#   'a',
#   'resonable',
#   'and',
#   'considered',
#   'manner',
#   'woulda',
#   'be',
#   'idea',
#   'zero',
#   'carbo',
#   'bill',
#   'target',
#   'unachievable',
#   'retiring',
#   'nationals',
#   'mp'],
#  ['love',
#   'a',
#   'good',
#   'challenges',
#   'posted',
#   'on',
#   'behalf',
#   'of',
#   'willie',
#   'and',
#   'angela',
#   'falloon',
#   'we',
#   'belive',
#   'we',
#   'all',
#   'have',
#   'a',
#   'part',
#   'to',
#   'play',
#   'improving',
#   'and',
#   'protecting',
#   'our',
#   'enviroment',
#   'we',
#   'dont',
#   'thinks',
#   'there',
#   'is',
#   'a',
#   'farmer',
#   'we',
#   'know',
#   'that',
#   'is',
#   'not',
#   'lookin',
#   'at'],
#  ['howd',
#   'you',
#   'travels',
#   'there',
#   'i',
#   'guarantee',
#   'it',
#   'involve',
#   'carbo',
#   'emission',
#   'whether',
#   'directly',
#   'or',
#   'indirectly',
#   'climathoax']]

# %%
cleaned_affirm_tweets
# Out:
#                      id       date      time  \
# 0   1177060829901885441 2019-09-25  20:22:25
# 1   1176786922687148032 2019-09-25  02:14:00
# 2   1164031877910618114 2019-08-20  21:30:01
# 3   1152577659710427136 2019-07-20  06:55:02
# 4   1146328119336460288 2019-07-03  01:01:36
# ..                  ...        ...       ...
# 1   1175370661985828865 2019-09-21  04:26:17
# 2   1169913415294259200 2019-09-06  03:01:08
# 3   1169535040792850437 2019-09-05  01:57:37
# 4   1169518364760276997 2019-09-05  00:51:21
# 5   1167707623803826176 2019-08-31  00:56:07
#
#                                                 tweet             mentions  \
# 0   #IPCC just released the #SROCC - a new report ...                   []
# 1   The #IPCC special report on ocean and ice is o...                   []
# 2   Unusually warm water surrounding one of the la...                   []
# 3   This is one of the hottest summers on record. ...                   []
# 4   Antarctic ice has taken a nosedive.\n\nThe amo...                   []
# ..                                                ...                  ...
# 1   As #GretaThunberg led the Climate Strike in Ne...                   []
# 2   The world is running out of time 🤜a race we ca...                   []
# 3   Will you Fight 🤜for the future! \n\nJoin us to...                   []
# 4   "Everyone has a responsible role towards tackl...  ['earthdaynetwork']
# 5   Join the Youth Voice for Climate Action campai...                   []
#
#     replies_count  retweets_count  likes_count  \
# 0               1              40           75
# 1               5              83          112
# 2               1              62           93
# 3               0              17           26
# 4               6             106          115
# ..            ...             ...          ...
# 1               0               0            2
# 2               0               1            5
# 3              14             149          277
# 4               0               3            6
# 5               0               3            6
#
#                                              hashtags username search_term  \
# 0                                 ['#ipcc', '#srocc']      350         ice
# 1                                 ['#ipcc', '#srocc']      350         ice
# 2                                                  []      350         ice
# 3                                     ['#abolishice']      350         ice
# 4                                                  []      350         ice
# ..                                                ...      ...         ...
# 1   ['#gretathunberg', '#nantichaocharoenchai', '#...    yv4ca     climate
# 2              ['#apclimateweek', '#apyouth4climate']    yv4ca     climate
# 3   ['#climateemergency', '#apclimateweek', '#apyo...    yv4ca     climate
# 4              ['#apclimateweek', '#apyouth4climate']    yv4ca     climate
# 5   ['#influencing', '#enhancing', '#mobilizing', ...    yv4ca     climate
#
#     label                                        tweet_clean
# 0       1  ipcc just released the srocc  a new report on ...
# 1       1  the ipcc special report on ocean and ice is ou...
# 2       1  unusually warm water surrounding one of the la...
# 3       1  this is one of the hottest summers on record t...
# 4       1  antarctic ice has taken a nosedivethe amount o...
# ..    ...                                                ...
# 1       1  as gretathunberg led the climate strike in new...
# 2       1  the world is running out of time a race we can...
# 3       1  will you fight for the future join us to empow...
# 4       1  everyone has a responsible role towards tackli...
# 5       1  join the youth voice for climate action campai...
#
# [230802 rows x 13 columns]

# %%
cleaned_affirm_tweets = tweet_imports('all_affirm_tweets.pkl')
cleaned_deny_tweets = tweet_imports('all_deny_tweets.pkl')

# %%
pro_sentences = [tk.tokenize(tweet.lower().split()) for tweet in cleaned_affirm_tweets['tweet_clean']]
anti_sentences = [tk.tokenize(tweet.lower().split()) for tweet in cleaned_deny_tweets['tweet_clean']]

# %%
# TO DO: fuzzy matching after MWE tokenization

# %%
fuzzy_pro_toks = [item for sublist in pro_sentences_fuzzy_matched for item in sublist]
fuzzy_anti_toks = [item for sublist in anti_sentences_fuzzy_matched for item in sublist]
#pro_toks = [item for sublist in pro_sentences for item in sublist if len(item) < 15]
#anti_toks = [item for sublist in anti_sentences for item in sublist if len(item) < 15]

# %%
pro_sentences[:5]
# Out:
# [['ipcc',
#   'just',
#   'released',
#   'the',
#   'srocc',
#   'a',
#   'new',
#   'report',
#   'on',
#   'oceans',
#   'and',
#   'ice',
#   'it',
#   'reminds',
#   'us',
#   'of',
#   'these',
#   'powerful',
#   'words',
#   'from',
#   'kathy',
#   'and',
#   'aka',
#   'one',
#   'year',
#   'ago',
#   'rewatch',
#   'the',
#   'stunning',
#   '6minute',
#   'film',
#   'at'],
#  ['the',
#   'ipcc',
#   'special',
#   'report',
#   'on',
#   'ocean',
#   'and',
#   'ice',
#   'is',
#   'out',
#   'and',
#   'well',
#   'be',
#   'honest',
#   'it',
#   'looks',
#   'bleak',
#   'but',
#   'we',
#   'know',
#   'what',
#   'must',
#   'be',
#   'done',
#   'the',
#   'age',
#   'of',
#   'fossil',
#   'fuels',
#   'must',
#   'endread',
#   'here',
#   'to',
#   'find',
#   'out',
#   'what',
#   'this',
#   'science',
#   'means',
#   'to',
#   'people',
#   'on',
#   'the',
#   'frontlines',
#   'srocc'],
#  ['unusually',
#   'warm',
#   'water',
#   'surrounding',
#   'one',
#   'of',
#   'the',
#   'largest',
#   'glaciers',
#   'in',
#   'greenland',
#   'isnt',
#   'good',
#   'newsa',
#   'billion',
#   'tons',
#   'of',
#   'ice',
#   'lost',
#   'here',
#   'raises',
#   'sea',
#   'levels',
#   'in',
#   'australia',
#   'in',
#   'southeast',
#   'asia',
#   'in',
#   'the',
#   'united',
#   'states',
#   'in',
#   'europe',
#   'we',
#   'are',
#   'all',
#   'connected',
#   'by',
#   'the',
#   'same',
#   'ocean'],
#  ['this',
#   'is',
#   'one',
#   'of',
#   'the',
#   'hottest',
#   'summers',
#   'on',
#   'record',
#   'the',
#   'heat',
#   'adds',
#   'to',
#   'the',
#   'cruelty',
#   'ice',
#   'inflictsthe',
#   'same',
#   'institutions',
#   'funding',
#   'migrant',
#   'incarceration',
#   'also',
#   'fund',
#   'the',
#   'fossil',
#   'fuel',
#   'companies',
#   'causing',
#   'the',
#   'climate',
#   'crisis',
#   'climate',
#   'justice',
#   'is',
#   'migrant',
#   'justice',
#   'abolishice'],
#  ['antarctic',
#   'ice',
#   'has',
#   'taken',
#   'a',
#   'nosedivethe',
#   'amount',
#   'of',
#   'ice',
#   'lost',
#   'in',
#   'antarctica',
#   'in',
#   'the',
#   'past',
#   '3',
#   'years',
#   'is',
#   'equivalent',
#   'to',
#   'the',
#   'amount',
#   'of',
#   'ice',
#   'the',
#   'arctic',
#   'has',
#   'lost',
#   'over',
#   '34',
#   'years']]

# %%
#pro_anti_log_odds_ratios = log_odds(pro_toks,anti_toks)
fuzzy_pro_anti_log_odds_ratios = log_odds(fuzzy_pro_toks,fuzzy_anti_toks)

# %%
#sorted_pro_anti_log_odds_ratios = sorted(pro_anti_log_odds_ratios.items(),key=lambda x:x[1],reverse=True)
fuzzy_sorted_pro_anti_log_odds_ratios = sorted(fuzzy_pro_anti_log_odds_ratios.items(),key=lambda x:x[1],reverse=True)

# %%
sorted_pro_anti_log_odds_ratios[:50]
# Out:
# [('rtdesmoguk', 8.18272521122586),
#  ('icym', 8.109490114325467),
#  ('go100re', 7.936759117681209),
#  ('waterislife', 7.167234908505245),
#  ('bikes4climate', 7.022305389143198),
#  ('climatecurate', 6.963684359190483),
#  ('notmx', 6.82901593928712),
#  ('rtclientearth', 6.7797713782944875),
#  ('rtcc', 6.527833836991624),
#  ('stoppipelines', 6.414473841443638),
#  ('climatemegan', 6.343901845604923),
#  ('globalactplan', 6.28869820638638),
#  ('inkl', 6.27311275447586),
#  ('rtmcswee', 6.191319717006068),
#  ('aces', 6.188516731153423),
#  ('wemeanit', 6.132821107357468),
#  ('powertoswitch', 6.004435134792601),
#  ('tarsands', 5.973500285610109),
#  ('jhiskes', 5.969587201986877),
#  ('deccorals', 5.969587201986877),
#  ('ue', 5.896116412284955),
#  ('trewinr', 5.872854451698635),
#  ('greenjobs', 5.857105614142179),
#  ('rospearce', 5.757019272060145),
#  ('rtcclive', 5.757019272060145),
#  ('paperli', 5.702976474440348),
#  ('propublica', 5.684257995432302),
#  ('sustcomm', 5.684257995432302),
#  ('peoplevscoal', 5.6555471686712915),
#  ('sierramagazine', 5.628556596706012),
#  ('100possible', 5.625987645551689),
#  ('cejapa', 5.625987645551689),
#  ('noborderwall', 5.615937069405617),
#  ('stopline3', 5.605784457649086),
#  ('askumbra', 5.605784457649086),
#  ('oneworldnews', 5.585164689861498),
#  ('sunrisemvmt', 5.564110800079044),
#  ('ottawacentre', 5.520624726970755),
#  ('nokxl', 5.516038541343553),
#  ('adaptourworld', 5.5094511860806366),
#  ('climaterescue', 5.475181970456437),
#  ('chloefarand', 5.475161391726371),
#  ('indc', 5.439653982394348),
#  ('lamontearths', 5.439653982394348),
#  ('naccnrm', 5.439653982394348),
#  ('ebikes', 5.427532381570414),
#  ('clientearth', 5.427532381570414),
#  ('natalielsauer', 5.427532381570414),
#  ('sightline', 5.402839288397037),
#  ('grist50', 5.377520999829974)]

# %%
fuzzy_sorted_pro_anti_log_odds_ratios[:50]
# Out:
# [('climat', 12.267923110255722),
#  ('hange', 11.271826079913485),
#  ('enrgy', 10.898404355987141),
#  ('carbn', 10.348500391902212),
#  ('arming', 9.874545755577772),
#  ('eople', 9.861134738259732),
#  ('climatechan', 9.821496237704082),
#  ('actio', 9.778008737359297),
#  ('futur', 9.226611615777788),
#  ('renwable', 9.096452253465934),
#  ('reort', 9.085873654668694),
#  ('supprt', 8.807205345296104),
#  ('indstry', 8.804274905066414),
#  ('polution', 8.787704066736486),
#  ('wether', 8.658588856463638),
#  ('pubic', 8.576571511808739),
#  ('greenewdeal', 8.560977624337001),
#  ('rtdesmoguk', 8.452811150100086),
#  ('impct', 8.441069789989495),
#  ('politcal', 8.329640851659924),
#  ('generatio', 8.182626864472995),
#  ('questin', 8.103099344095229),
#  ('climateation', 8.10073160723265),
#  ('billon', 8.087607959629398),
#  ('someting', 8.066981261748223),
#  ('efficency', 8.064526400945745),
#  ('mthane', 8.050915953778539),
#  ('go100re', 8.049669411780211),
#  ('atmosphre', 7.944551069975746),
#  ('systm', 7.9064260073418),
#  ('transtion', 7.893387866431703),
#  ('likel', 7.890467284536861),
#  ('rowing', 7.844072983519561),
#  ('fightin', 7.805025123528861),
#  ('sutainable', 7.805025123528861),
#  ('addess', 7.797029296425871),
#  ('aways', 7.774294942991301),
#  ('pastic', 7.740894141344711),
#  ('devopment', 7.722037031724342),
#  ('panelsnotpiplines', 7.7150908158713545),
#  ('temprature', 7.713346700391958),
#  ('serous', 7.711599539182637),
#  ('targe', 7.708096036883247),
#  ('politican', 7.685019249637232),
#  ('progess', 7.683221868089191),
#  ('projet', 7.672369236841078),
#  ('breit', 7.644711167480372),
#  ('climatstrike', 7.633430237242555),
#  ('fooprint', 7.627741710524476),
#  ('infastructur', 7.614341329898494)]

# %%
sorted_pro_anti_log_odds_ratios[-50:]
# Out:
# [('irradiance', -5.933890595199233),
#  ('credlin', -5.933890595199233),
#  ('breitbartnews', -5.952795615652895),
#  ('planethealing', -5.952795615652895),
#  ('alberta411', -5.956534110926493),
#  ('psiintl', -5.960258683180498),
#  ('vanpoli', -5.969556770606905),
#  ('climatescambs', -5.98231944022399),
#  ('gh', -5.993169975737841),
#  ('dmsp', -6.003904050871004),
#  ('climatecult', -6.007456625638784),
#  ('ir', -6.010651806261905),
#  ('imager', -6.010996625507349),
#  ('metop', -6.014524139188789),
#  ('avhrr', -6.014524139188789),
#  ('seviri', -6.014524139188789),
#  ('havenr64', -6.018039254459735),
#  ('mapsnorthern', -6.059284290958141),
#  ('craighavenr', -6.072663109560062),
#  ('ilmastonmuutos', -6.121297655861416),
#  ('multisensor', -6.1244573893162455),
#  ('caca', -6.136997431227124),
#  ('junkscience', -6.164650521040213),
#  ('adiabatic', -6.188605147382592),
#  ('joannenova', -6.247553423524605),
#  ('snowice', -6.251667092989312),
#  ('adapt2030', -6.27906779883658),
#  ('latestnews', -6.357034535301745),
#  ('gotminiiceage', -6.4386204099883075),
#  ('ecosensenow', -6.454621963511374),
#  ('daviddubyne', -6.511910848116615),
#  ('cultist', -6.535194227799702),
#  ('earthchanges', -6.537284265888481),
#  ('icleiagenda21', -6.566095266893869),
#  ('littleiceage', -6.574176811627062),
#  ('miniiceage', -6.590146600165742),
#  ('grandsolar', -6.623258702669285),
#  ('warmists', -6.632883674200139),
#  ('jonova', -6.66454417140356),
#  ('notrickszone', -6.762638066435059),
#  ('amazonca', -6.929479024749682),
#  ('climatecon', -6.993673013713083),
#  ('drtimball', -7.295194474610706),
#  ('unreliables', -7.531990958772318),
#  ('pplonia', -7.557160030087031),
#  ('premeditated', -7.558665267656106),
#  ('ccdeditor', -7.614248281706688),
#  ('co2induced', -7.692492747207848),
#  ('co2agw', -8.10743299529493),
#  ('jwspry', -8.540254609865913)]

# %%
fuzzy_sorted_pro_anti_log_odds_ratios[-50:]
# Out:
# [('levels', -7.80691751399),
#  ('youare', -7.811587593893603),
#  ('claims', -7.8309203763520205),
#  ('agreat', -7.837012642822188),
#  ('powers', -7.83958805564201),
#  ('rnewable', -7.851085388413272),
#  ('wrongi', -7.88059120171805),
#  ('policya', -7.887545056452793),
#  ('repor', -7.887545056452793),
#  ('criss', -7.888314733906715),
#  ('theory2', -7.929391724881963),
#  ('temperatur', -7.941137817679738),
#  ('scietific', -7.958143841771789),
#  ('increse', -7.967784201426193),
#  ('every1', -7.977684528447237),
#  ('earths', -7.980254165279339),
#  ('goings', -7.984696732325617),
#  ('atmospherc', -7.993393488140591),
#  ('jspry', -8.011244339861102),
#  ('neverb', -8.097577921431014),
#  ('tmosphere', -8.109677928228338),
#  ('coulds', -8.112142012409521),
#  ('lttle', -8.118581534353247),
#  ('cdnoli', -8.18050972949076),
#  ('youtubes', -8.195057503808066),
#  ('uspol', -8.21329767816101),
#  ('contro', -8.253363089487692),
#  ('caused', -8.257362715667853),
#  ('thatso', -8.286990643569734),
#  ('belive', -8.30440647774254),
#  ('recor', -8.358041406649438),
#  ('suface', -8.363322113100685),
#  ('greehouse', -8.422356022271284),
#  ('fossils', -8.459356709113152),
#  ('thinks', -8.559859133143267),
#  ('cooing', -8.666526019478642),
#  ('weater', -8.730595851553684),
#  ('evidenced', -8.739517400166966),
#  ('climatechage', -8.777760784525398),
#  ('solars', -8.964185140286208),
#  ('peoples', -9.039878897919898),
#  ('woulda', -9.066468450349417),
#  ('carbo', -9.21107825087047),
#  ('chang', -9.221929825455488),
#  ('years3', -9.35872235855896),
#  ('sience', -9.673290976318965),
#  ('enegy', -10.020283610245922),
#  ('globa', -10.248001127832564),
#  ('warmin', -10.311441669313718),
#  ('clmate', -10.458798630581489)]
